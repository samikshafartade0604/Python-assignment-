# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshafartade0604/Python-assignment-/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ch = input("Enter a character: ")

if ch.isupper():
    print("Uppercase letter")
elif ch.islower():
    print("Lowercase letter")
else:
    print("Not an alphabet")
# Out:
# Enter a character: S
# Uppercase letter
