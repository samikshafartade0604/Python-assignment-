# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshafartade0604/Python-assignment-/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = input("Enter something: ")

if x.isdigit():
    print("It is a number")
else:
    print("It is a character")
# Out:
# Enter something: A
# It is a character
